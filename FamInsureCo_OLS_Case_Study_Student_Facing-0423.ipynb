# %% [markdown]
# <center> <h2><b style="color:teal"> Welcome to the FamInsureCo Python Case Study! </b></h2>

# %% [markdown]
# <img src = "https://globalselect.com.au/wp-content/uploads/2022/08/Health-Insurance-img-1.jpg" width="600" height="300">

# %% [markdown]
# While working on the Statistics unit, you used Microsoft Excel's data analytics capabilities to analyze FamInsureCo's Data
#
# You might have realised that whilst Excel is powerful, it was a bit tricky creating Box Plots, multiple line plots and in general, doing quick analysis in Excel. You had to use a lot of filters to subset the data, which, then provided your charts were linked, created a number of issues with your other visuals.
#
# In this Case Study, we're going to *revisit* the FamInsureCo Case Study, but with a few added questions that will really emphasise how Python can speed up our analysis and improve our data visualisation capabilities!
#
#
# **Please note that this case study is composed of two parts** — once you have completed part 1, which involves descriptive statistics, please submit your work and discuss it with your mentor <u>before</u> moving on to part 2.
#
# Let's get started!

# %% [markdown]
# ## Part I: <span style="color:Purple">Basic Descriptive Statistical Analysis</span>

# %% [markdown]
# <h2><b style="color:teal">Descriptive Statistics</b></h2>

# %% [markdown]
# ### Step 1: <span style="color:teal">Import Libraries & Set Plot Styles</span>
#
# Import the libraries you'll need for your analysis. You will need the following libraries:
#
# **Matplotlib** - This is Python's basic plotting library.
#
# **Pandas** - This library will enable you to view and manipulate your data in a tabular format.
#
#
# Please note we've included the `mpl.rcParams['figure'figsize']` code for you.
#
# This code controls how big your charts will be with the syntax of (X,Y) where X represents the X Axis and Y, the Y Axis.

# %% [markdown]
# <h2><b style="color:salmon"> Run the code we've provided below </b> </h2>

# %%
# !pip install pandas==1.5.3

# %%
import pandas as pd 
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (8,5) #Setting up the plotting visualization range
import warnings 
warnings. filterwarnings('ignore') 
import pandas as pd

# %% [markdown]
# ### Step 2: <span style="color:teal">Descriptive Statistics</span>
# The data you'll need to complete the FamInsureCo Case Study is separated into two files.
#
# <li> <b>  data_source_1 : </b> This contains the dataset for the <b> basic descriptive statistics </b> we will be performing.</li>
#
#
# <li> <b>  data_source_2 : </b> This contains the dataset for the <b> intermediate descriptive statistics </b> we will be performing. </li>
#
# <b>Using the `data_source_1` and `data_source_2` variables alongside the `pd.read_csv()` method, create two dataframes titled `descriptive_df` and `intermediate_df` that contains the respective data sources. Use the `.head()` method on any of the two dataframes to validate you have correctly loaded the data.

# %% [markdown]
# <h2><b style="color:salmon"> Place your code here </b> </h2>

# %%
data_source_1 = 'https://raw.github.com/chrishuisb1990/practice_datasets/main/FIC_Descriptive_Statistics_Data.csv'
data_source_2 = 'https://raw.github.com/chrishuisb1990/practice_datasets/main/FIC_Intermediate_Descriptive_Statistics_Data.csv'

# %% [markdown]
# <h2><b style="color:salmon"> Sample Output </b> </h2>

# %%
pd.read_csv(data_source_1).head()

# %% [markdown]
# ### Step 3: <span style="color:teal">Create a Single Scatter Plot </span>
#
# Previously, when we kicked off our analysis in Excel, we started with some Scatter Plots.
#
# As a quick refresher, scatter plots are a useful way to compare two variables and determining whether any relationship might exist between them. We've included an example below of what this looks like to jog your memory.
#
# <img src = "https://seaborn.pydata.org/_images/scatterplot_3_0.png">

# %% [markdown]
# <b> Create a Scatter Plot highlighting the Medical Insurance Costs (Y-Axis) against the Body mass Index (X-Axis) using the `descriptive_df` dataframe you created earlier. </b>
#
# <b> Hint: If you're stuck, refer back to the Visualization lecture slides highlighting the scatter plot syntax! </b>

# %% [markdown]
# <h2 style="color:teal"> Write your answer below </h2>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load and clean data
url = 'https://raw.githubusercontent.com/chrishuisb1990/practice_datasets/main/FIC_Descriptive_Statistics_Data.csv'
df = pd.read_csv(url)
df.columns = df.columns.str.strip()  # Just in case

# Plot
plt.scatter(df['bmi'], df['medical_insurance_charges'], alpha=0.6)
plt.xlabel('BMI')
plt.ylabel('Medical Insurance Charges')
plt.title('Medical Insurance Charges vs BMI')
plt.show()

# %% [markdown]
# <h2><b style="color:salmon"> Sample Output </b> </h2>

# %% [markdown]
# ### Step 4: <span style="color:teal"> Data Preparation & Aggregations </span>

# %% [markdown]
# Using the `.groupby()` and `.agg()` skills you've learned, aggregate the data in the `descriptive_df` dataframe, to showcase the `Total_Number_Individuals` in the weight classification (`bmi_classification`) column, as well as the `mean`, `sum` and `std` of the `medical_insurance_charges` column. Store this in a dataframe called `aggregated_df`.
#
# <b> Hint: In case you can't remember the syntax, we've included a sample from the lecture slides to help you recall this! </b>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h2 style="color:teal"> Write your answer below </h2>

# %%
# Group by 'bmi_classification' and aggregate the required stats
aggregated_df = descriptive_df.groupby('bmi_classification').agg(
    Total_Number_Individuals=('medical_insurance_charges', 'count'),
    Mean_Charges=('medical_insurance_charges', 'mean'),
    Sum_Charges=('medical_insurance_charges', 'sum'),
    Std_Charges=('medical_insurance_charges', 'std')
).reset_index()

# Display the result
aggregated_df
# Out:
#     bmi_classification  Total_Number_Individuals  Mean_Charges   Sum_Charges  \
# 0              Healthy                       221  10404.900084  2.299483e+06
# 1           Overweight                       716  15491.542238  1.109194e+07
# 2  Slightly Overweight                       380  11006.809989  4.182588e+06
# 3          Underweight                        21   8657.620652  1.818100e+05
#
#     Std_Charges
# 0   7508.165722
# 1  14508.128111
# 2   8004.176052
# 3   7591.730101

# %% [markdown]
# <h2><b style="color:salmon"> Sample Output </b> </h2>

# %%
# Out:
#                      count          mean           sum           std
# bmi_classification
# Healthy                221  10404.900084  2.299483e+06   7508.165722
# Overweight             716  15491.542238  1.109194e+07  14508.128111
# Slightly Overweight    380  11006.809989  4.182588e+06   8004.176052
# Underweight             21   8657.620652  1.818100e+05   7591.730101

# %% [markdown]
# ### Step 5: <span style="color:teal"> Multiple Visualizations using Subplot Syntax</span>

# %% [markdown]
# With our `aggregated_df` prepared, we're now ready to create the below visualizations.
#
# Please go ahead and create <b> 3 </b> visualizations using the `plt.subplot(x,y,z)` syntax you've been taught where `x` represents the number of rows, `y` the number of columns and `z` the position of the chart.
#
# 1. Create a Scatter Plot showing the `count` and `mean` columns in the `aggregated_df` dataframe.
#
# 2. Create a Scatter Plot showing the `count` and `sum` columns in the `aggregated_df` dataframe.
#
# 3. Create a Scatter Plot showing the `count` and `std` columns in the `aggregated_df` dataframe.
#
# Hint: Here's an example to get you started regarding the plotting syntax.
#
# `fig, axes = plt.subplots(1, 3, figsize=(15, 5))`
#
# `df.plot(kind='scatter', x='count', y='mean', ax=axes[0])`
#
# `axes[0].set_title("Count vs Mean")`
#
# Note that we specify the `ax=axes[]` argument to let Python know which axes object we are referring to.
#
# It's almost identical to writing:
#
# `plt.subplot(1,3,1)`

# %% [markdown]
# <h2 style="color:teal"> Write your answer below </h2>

# %%
import matplotlib.pyplot as plt

# Create 3 subplots side by side
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# First Plot: Count vs Mean
aggregated_df.plot(kind='scatter', 
                   x='Total_Number_Individuals', 
                   y='Mean_Charges', 
                   ax=axes[0], 
                   color='teal')
axes[0].set_title("Count vs Mean Charges")
axes[0].set_xlabel("Total Number of Individuals")
axes[0].set_ylabel("Mean Charges")

# Second Plot: Count vs Sum
aggregated_df.plot(kind='scatter', 
                   x='Total_Number_Individuals', 
                   y='Sum_Charges', 
                   ax=axes[1], 
                   color='orange')
axes[1].set_title("Count vs Sum Charges")
axes[1].set_xlabel("Total Number of Individuals")
axes[1].set_ylabel("Sum Charges")

# Third Plot: Count vs Std
aggregated_df.plot(kind='scatter', 
                   x='Total_Number_Individuals', 
                   y='Std_Charges', 
                   ax=axes[2], 
                   color='purple')
axes[2].set_title("Count vs Std Charges")
axes[2].set_xlabel("Total Number of Individuals")
axes[2].set_ylabel("Standard Deviation of Charges")

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# <h2><b style="color:salmon"> Sample Output </b> </h2>

# %% [markdown]
# ### Step 6: <span style="color:teal"> Adding legends to your Scatter Plot Visualization </span>

# %% [markdown]
# <b> Having created the respective scatter plot visualizations, color each data point to indicate the respective `bmi_classification` and add this legend at the bottom of the 3 scatter plot sub plots. </b>
#
# <b> Hint: This is a little tricky so we've included a detail hint below to walkthrough this process! </b>

# %% [markdown]
# <h3>... But how can we tell which scatter plot refers to which weight classification? </h3>
#
# This is where we'll need to make use of the `c` argument in our `.plot()` method, which is shorthand for color.
# In a nutshell, we're going to have to define a <b> dictionary object </b> that maps the `bmi_classification` to a specific color.
#
# In other words, something like this:
#
# `colors = {'Underweight': 'Orange', 'Healthy': 'green', 'Slightly Overweight': 'blue', 'Overweight': 'red' }`
#
# For a list of colors, go <a href = "https://matplotlib.org/stable/gallery/color/named_colors.html"> here</a>
#
# We would then <b> map </b> this back to our plot accordingly using the `c` argument.
#
# `df.plot(kind='scatter', x='a', y='b', c=df.index.map(colors))`
#
# Think of the `.map()` as applying the color dictionary to the `df['bmi_classification']` column, which is now the `index` due to the `group by`.

# %% [markdown]
# Lastly, with the colors now applied, we need to create the legend.
#
# #### 1. Specify the 3 sub plots plotting coordinates
#     fig, axes = plt.subplots(1, 3, figsize=(15, 5))
#
# #### 2. Specify the color dictionary for our scatter plot
#     colors = {'Underweight': 'Orange', 'Healthy': 'green', 'Slightly Overweight': 'blue', 'Overweight': 'red' }
#
# #### 3. Plotting the scatter plots with color categories
#     df.plot(kind='scatter', x='count', y='mean', c=df.index.map(colors), ax=axes[0])
#     axes[0].set_title("Count vs Mean")
#
#     Repeat this for the 2nd and 3rd Scatter Plots
#
# #### 4. Lastly, add the legend in for the respective color scales.
#     handles = []
#     for label, color in colors.items():
#         handles.append(plt.Line2D([], [], marker='o', color=color, label=label, linestyle='None'))
#     fig.legend(handles, colors.keys(), loc='center', bbox_to_anchor=(0.5, -0.1), fancybox=True, shadow=True, ncol=4)
#
#     plt.tight_layout()
#     plt.show()

# %% [markdown]
# Now it's your turn to implement this below!

# %% [markdown]
# <h2 style="color:teal"> Write your answer below </h2>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define color dictionary for BMI categories
colors = {
    'Underweight': 'orange',
    'Healthy': 'green',
    'Slightly Overweight': 'blue',
    'Overweight': 'red'
}

# Create a color map column based on bmi_classification
aggregated_df['color'] = aggregated_df['bmi_classification'].map(colors)

# Create subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Plot 1: Count vs Mean Charges
axes[0].scatter(
    aggregated_df['Total_Number_Individuals'], 
    aggregated_df['Mean_Charges'], 
    c=aggregated_df['color']
)
axes[0].set_title("Count vs Mean Charges")
axes[0].set_xlabel("Total Number of Individuals")
axes[0].set_ylabel("Mean Charges")

# Plot 2: Count vs Sum Charges
axes[1].scatter(
    aggregated_df['Total_Number_Individuals'], 
    aggregated_df['Sum_Charges'], 
    c=aggregated_df['color']
)
axes[1].set_title("Count vs Sum Charges")
axes[1].set_xlabel("Total Number of Individuals")
axes[1].set_ylabel("Sum Charges")

# Plot 3: Count vs Std Charges
axes[2].scatter(
    aggregated_df['Total_Number_Individuals'], 
    aggregated_df['Std_Charges'], 
    c=aggregated_df['color']
)
axes[2].set_title("Count vs Std Charges")
axes[2].set_xlabel("Total Number of Individuals")
axes[2].set_ylabel("Standard Deviation of Charges")

# Create legend handles
handles = [
    plt.Line2D([], [], marker='o', color=color, label=label, linestyle='None')
    for label, color in colors.items()
]

# Add legend below plots
fig.legend(
    handles, 
    colors.keys(), 
    loc='center', 
    bbox_to_anchor=(0.5, -0.15), 
    fancybox=True, 
    shadow=True, 
    ncol=4
)

# Final layout adjustment
plt.tight_layout()
plt.show()

# %% [markdown]
# <h2><b style="color:salmon"> Sample Output </b> </h2>

# %% [markdown]
# ### Step 7: <span style="color:teal"> Micro Scatter Plot Analysis </span>
#
# Now it's clear we see some apparent linear relationship when we've aggregated the data substantially.
# However, is this relationship still apparent when we look at the data in more granular detail?
#
# Create a Scatter Plot using the `descriptive_df` dataframe that charts the `bmi` against the `medical_insurance_charges`, colored by the color scheme we defined in the previous question.

# %% [markdown]
# <h2 style="color:teal"> Write your answer below </h2>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Set up plotting style
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (10, 6)

# Load the descriptive dataset
data_source_1 = 'https://raw.githubusercontent.com/chrishuisb1990/practice_datasets/main/FIC_Descriptive_Statistics_Data.csv'
descriptive_df = pd.read_csv(data_source_1)

# Clean column names
descriptive_df.columns = descriptive_df.columns.str.strip()

# Define color map for BMI classification
colors = {
    'Underweight': 'orange',
    'Healthy': 'green',
    'Slightly Overweight': 'blue',
    'Overweight': 'red'
}

# Map colors to each row
color_map = descriptive_df['bmi_classification'].map(colors)

# Create the scatter plot
plt.scatter(
    descriptive_df['bmi'], 
    descriptive_df['medical_insurance_charges'], 
    c=color_map, 
    alpha=0.6
)
plt.xlabel('BMI')
plt.ylabel('Medical Insurance Charges')
plt.title('Individual Medical Charges vs BMI (Colored by BMI Classification)')

# Add legend manually
handles = [
    plt.Line2D([], [], marker='o', color=color, label=label, linestyle='None')
    for label, color in colors.items()
]
plt.legend(handles=handles, title='BMI Classification', loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# <h2><b style="color:salmon"> Sample Output </b> </h2>

# %% [markdown]
# ### Step 8: <span style="color:teal"> Segmentation by Smoker Status</span>

# %% [markdown]
# Now we may recall that we happened to see a particularly interesting observation when we filtered our data on `smoking status`. We saw costs uptick for a certain subset of our population - namely our Smokers. We've clearly seen the power of adding colors to our scatter plots, so it's only right we explore how this changes with our `smoker` category.
#
# Using the `descriptive_df` dataframe, create a Scatter Plot that charts the bmi against the medical_insurance_charges, colored by the `smoker` status.
#
# Note that you'll need to define a <b> new </b> dictionary for the smoker status outcomes (i.e. yes or no).

# %% [markdown]
# <h2 style="color:teal"> Write your answer below </h2>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load and clean dataset (in case it's not loaded yet)
data_source_1 = 'https://raw.githubusercontent.com/chrishuisb1990/practice_datasets/main/FIC_Descriptive_Statistics_Data.csv'
descriptive_df = pd.read_csv(data_source_1)
descriptive_df.columns = descriptive_df.columns.str.strip()

# Define color map for smoker status
smoker_colors = {
    'yes': 'red',
    'no': 'green'
}

# Map colors to smoker column
color_map = descriptive_df['smoker'].map(smoker_colors)

# Create scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(
    descriptive_df['bmi'],
    descriptive_df['medical_insurance_charges'],
    c=color_map,
    alpha=0.6
)

plt.xlabel('BMI')
plt.ylabel('Medical Insurance Charges')
plt.title('Medical Charges vs BMI (Colored by Smoker Status)')

# Create legend manually
handles = [
    plt.Line2D([], [], marker='o', color=color, label=label, linestyle='None')
    for label, color in smoker_colors.items()
]
plt.legend(handles=handles, title='Smoker Status', loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# <h2><b style="color:salmon"> Sample Output </b> </h2>

# %% [markdown]
# ### Step 9: <span style="color:teal"> Segmentation by Smoker Status - Histograms</span>
#
# It's clear to see that Smoker Status has a part to play in relation to `medical_insurance_charges`, but how might this look via a Histogram?
#
# Create two histogram distributions using the `descriptive_df` dataframe, showcasing the distribution <b> with </b> smoking and <b> without </b> smoking.

# %% [markdown]
# <h2 style="color:teal"> Write your answer below </h2>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load and clean data
url = 'https://raw.githubusercontent.com/chrishuisb1990/practice_datasets/main/FIC_Descriptive_Statistics_Data.csv'
df = pd.read_csv(url)
df.columns = df.columns.str.strip()

# Filter smoker groups
smokers = df[df['smoker'] == 'yes']
non_smokers = df[df['smoker'] == 'no']

# Create the histograms in two subplots
plt.figure(figsize=(14, 5))

# Left plot: Smokers
plt.subplot(1, 2, 1)
plt.hist(smokers['medical_insurance_charges'], bins=40, color='red', alpha=1)
plt.title('Histogram - Smoker Status = Yes')
plt.xlabel('Medical Insurance Charges')
plt.ylabel('Frequency')

# Right plot: Non-Smokers
plt.subplot(1, 2, 2)
plt.hist(non_smokers['medical_insurance_charges'], bins=40, color='red', alpha=1)
plt.title('Histogram - Smoker Status = No')
plt.xlabel('Medical Insurance Charges')
plt.ylabel('Frequency')

# Display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# <h2><b style="color:salmon"> Sample Output </b> </h2>

# %% [markdown]
# And that's a wrap for Part 1!
#
# We've had you work on your Python Visualizations where you've used your `.agg()` capabilities and your `matplotlib` competencies to create some insightful visualizations! Now take a breather before starting Part 2!

# %% [markdown]
# ## Part II: <span style="color:Purple">Intermediate Statistical Analysis</span>

# %% [markdown]
# ### Step 10: <span style="color:teal"> Box Plots </span>

# %% [markdown]
# Now you might recall that we had created some Box Plot visualisations in Excel.
# These were a little frustrating due to the filters in Excel that would impact your linked charts.
# Thankfully, Python, and subsequently, `matplotlib` make creating box plots much easier.
#
# Now we haven't yet examined the impact of Smoking and Region - let's see if there is any notable impact in relation to our medical insurance charges!
#
# Please create:
#
# <b> 2 Box Plots showcasing the spread of Medical Insurance Costs with respect to Gender and Smoker Status using the `descriptive_df`. </b>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h2 style="color:teal"> Write your answer below </h2>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load and clean data
url = 'https://raw.githubusercontent.com/chrishuisb1990/practice_datasets/main/FIC_Descriptive_Statistics_Data.csv'
df = pd.read_csv(url)
df.columns = df.columns.str.strip()

# Filter smoker groups
smokers = df[df['smoker'] == 'yes']
non_smokers = df[df['smoker'] == 'no']

# Create side-by-side boxplots
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Boxplot for smokers (left)
smokers.boxplot(column='medical_insurance_charges', by='region', ax=axes[0],
                patch_artist=True, boxprops=dict(facecolor='lightcoral'), medianprops=dict(color='black'))
axes[0].set_title('Boxplot - Smoker Status = Yes')
axes[0].set_xlabel('Region')
axes[0].set_ylabel('Medical Insurance Charges')
axes[0].set_ylim(0, 65000)  # Custom range for smokers

# Boxplot for non-smokers (right)
non_smokers.boxplot(column='medical_insurance_charges', by='region', ax=axes[1],
                    patch_artist=True, boxprops=dict(facecolor='lightblue'), medianprops=dict(color='black'))
axes[1].set_title('Boxplot - Smoker Status = No')
axes[1].set_xlabel('Region')
axes[1].set_ylim(0, 40000)  # Custom range for non-smokers

# Main title
plt.suptitle('Medical Charges by Region, Segmented by Smoker Status', fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# <h2><b style="color:salmon"> Sample Output </b> </h2>

# %% [markdown]
# ### Step 11: <span style="color:teal"> Segmentation by Gender (Sex) </span>

# %% [markdown]
# Now we know that there appears to be a Hypotheses that one of the two sexes, may have higher medical insurance costs.
#
# However, we know that this isn't isolated only to gender.
#
# Smoking Status obviously has a larger role to play here
#
# <b>Create a Box Plot where the `hue` is set to `smoker` with the X-Axis set to Gender (`i.e. sex`). What do you observe? </b>

# %% [markdown]
# <h2 style="color:teal"> Write your answer below </h2>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load and clean dataset
url = 'https://raw.githubusercontent.com/chrishuisb1990/practice_datasets/main/FIC_Descriptive_Statistics_Data.csv'
df = pd.read_csv(url)
df.columns = df.columns.str.strip()

# Split by smoker status
smokers = df[df['smoker'] == 'yes']
non_smokers = df[df['smoker'] == 'no']

# Create figure and subplots
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Left Plot: Smoker = Yes
smokers.boxplot(column='medical_insurance_charges', by='sex', ax=axes[0],
                patch_artist=True,
                boxprops=dict(color='black'), medianprops=dict(color='red'))
axes[0].set_title('Boxplot - Smoker Status = Yes')
axes[0].set_xlabel('Sex')
axes[0].set_ylabel('Medical Insurance Charges')
axes[0].set_ylim(0, 65000)  # Custom Y-axis

# Right Plot: Smoker = No
non_smokers.boxplot(column='medical_insurance_charges', by='sex', ax=axes[1],
                    patch_artist=True,
                    boxprops=dict(color='black'), medianprops=dict(color='red'))
axes[1].set_title('Boxplot - Smoker Status = No')
axes[1].set_xlabel('Sex')
axes[1].set_ylabel('')
axes[1].set_ylim(0, 40000)  # Custom Y-axis

# Add main title
plt.suptitle('Boxplot grouped by sex', fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# <h2><b style="color:salmon"> Sample Output </b> </h2>

# %% [markdown]
# <h3> <span style="color:orange"> Please note that Step 12 and 13 are Challenge Questions and will intentionally be more difficult </h3>

# %% [markdown]
# ### Step 12: <span style="color:teal"> Create Quartiles</span>
#
# Now we haven't done any particular treatments to our data analysis.
# In our case, we might have <b> Outliers </b> in our Medical Insurance Charges that can skew our dataset.
#
# We're going to be looking at running some correlations later as part of our Intermediate Statistics Analysis, but before that, it's important we treat our data and ensure we remove our Outliers. Take a look at the image below; you should be able to clearly identify the data point that is different from the rest.
#
# If you were to take the average including that data point, the average would be inflated, when in fact that data point isn't representative of the series. Generally, we would remove Outliers to ensure we have a representative population mean, or, use the median.
#
# Now let's see what happens if we are to remove our Outliers.
#
# <img src = https://images.ctfassets.net/kj4bmrik9d6o/cESitsCxzL2ijivbNwiW6/de9421d4c144e5a5c23c35941931c83f/Outlier_Graph_CalculateOutlierFormula-01.png>
#
# To do this, we'll have you perform the below:
#
# Create two new variables called `Q1 and Q3` using the `intermediate_df` Dataframe, focusing specifically on the <b> medical insurance charges </b> column.
#
# <b> i) Q1 should contain the 25th percentile for all columns in the dataframe while Q3 should contain the 75th percentile for all the columns in the dataframe. </b>
#
# You may want to use the .quantile() function explained <a href = https://www.geeksforgeeks.org/python-pandas-dataframe-quantile/> here </a>
#
# <b>ii) After defining Q1 and Q3, calculate the interquartile range **(IQR = Q3 - Q1)** for all columns in the dataframe and print it to the screen.</b>
#
# We've included a sample of the IQR output below for your reference!

# %% [markdown]
# <h2 style="color:teal"> Write your answer below </h2>

# %%
import pandas as pd

# Load the intermediate dataset
url = 'https://raw.githubusercontent.com/chrishuisb1990/practice_datasets/main/FIC_Intermediate_Descriptive_Statistics_Data.csv'
intermediate_df = pd.read_csv(url)
intermediate_df.columns = intermediate_df.columns.str.strip()

# Step 1: Calculate Q1 (25th percentile)
Q1 = intermediate_df.quantile(0.25)

# Step 2: Calculate Q3 (75th percentile)
Q3 = intermediate_df.quantile(0.75)

# Step 3: Calculate IQR (Interquartile Range)
IQR = Q3 - Q1

# Step 4: Display results
print("Q1 (25th percentile):\n", Q1, "\n")
print("Q3 (75th percentile):\n", Q3, "\n")
print("IQR (Q3 - Q1):\n", IQR)
# Out:
# Q1 (25th percentile):
#  age                            27.00000
# bmi                            26.29625
# BMI_Healthy                     0.00000
# BMI_Overweight                  0.00000
# BMI_Slightly_Overweight         0.00000
# BMI_Underweight                 0.00000
# Biological Marker               0.00000
# Smoker                          0.00000
# southeast                       0.00000
# southwest                       0.00000
# northwest                       0.00000
# northeast                       0.00000
# Young Adult                     0.00000
# Adult                           0.00000
# Mature Age Adult                0.00000
# Senior                          0.00000
# medical_insurance_charges    4740.28715
# Name: 0.25, dtype: float64
#
# Q3 (75th percentile):
#  age                             51.000000
# bmi                             34.693750
# BMI_Healthy                      0.000000
# BMI_Overweight                   1.000000
# ...

# %% [markdown]
# <h2><b style="color:salmon"> Sample Output </b> </h2>

# %%
# Out:
# 11899.625365

# %% [markdown]
# The general logic for removing an outliers is:
#
# <b> Any Value that is either Q1 - 1.5x IQR or greater than Q3 + 1.5x IQR is considered an outlier. </b>
#
# Where Q1 = Quartile 1 and Q3 = Quartile 3
#
# Let's break these down to a few simple steps and tackle how to calculate this.
#
# 1. Define the Quartiles Q1 and Q3.
# 2. Calculate the Interquartile Range (Q3 - Q1)
# 3. Create two new variables; Lower_Range (Q1 - 1.5x IQR) and Upper_Range ( Q3 + 1.5x IQR).
# 4. Using Boolean Subsetting, filter the Dataframe for Outliers and remove them
# 5. Calculate what the proportion of Outliers exist (i.e. Number of entries left after Outlier removal / Number of total entries in dataset)

# %% [markdown]
# ### Step 13: <span style="color:teal"> Identify & Remove Outliers</span>
#
# Continuing in from Step 12 - we still need to calculate <b>how</b> we can remove our outliers.
#
# We're aware of the overall formula as shown per below.
#
# <b> Outlier = Q1 - 1.5x IQR OR Q3 + 1.5x IQR </b>
#
# Now let's work out how we can identify these Outliers step by step.
#
# <b> i) Define two new variables, Lower_Limit and Upper_Limit can be calculated as:</b>
# <p>
# <li> Lower_Limit = Q1 - 1.5 * IQR </li>
# <li> Upper_Limit = Q3 + 1.5 * IQR </li>
#
# <b> ii) Using Lower_Limit and Upper_Limit with an OR (|) condition, filter the dataframe to include *only* the Outliers. How many Outliers do we have?</b>
#
# <b>Now note that we only want to use the *upper limit* for our filtering.
# This is because the lower limit has us retrieve -ve medical insurance charges, which isn't valid. </b>
#
# What this means is that the syntax should look like this:
#
#     intermediate_df_outliers = some_dataframe [ (some_dataframe > Upper_Limit)]
#
# If you're stuck, <a href = https://stackoverflow.com/questions/54398554/how-to-remove-outliers-in-python> here's </a> a link that will show you how you can remove Outliers in Python!
#
# <b> iii) What is the percentage of data that remains after we've removed the Outliers from the `FamInsureCo` dataset?</b>

# %% [markdown]
# <h2 style="color:teal"> Write your answer below </h2>

# %%
import pandas as pd

# Load and clean the dataset
url = 'https://raw.githubusercontent.com/chrishuisb1990/practice_datasets/main/FIC_Intermediate_Descriptive_Statistics_Data.csv'
df = pd.read_csv(url)
df.columns = df.columns.str.strip()

# Calculate Q1, Q3, IQR for the medical_insurance_charges column
Q1 = df['medical_insurance_charges'].quantile(0.25)
Q3 = df['medical_insurance_charges'].quantile(0.75)
IQR = Q3 - Q1

# Calculate the upper limit only (we ignore the lower limit)
upper_limit = Q3 + 1.5 * IQR

# ✅ Filter to get the outliers — this will keep the original row numbers
outliers_df = df[df['medical_insurance_charges'] > upper_limit]

# ✅ Display the outlier DataFrame with original index
outliers_df
# Out:
#       age     bmi  BMI_Healthy  BMI_Overweight  BMI_Slightly_Overweight  \
# 214    45  22.895            1               0                        0
# 480    59  34.800            0               1                        0
# 489    61  33.330            0               1                        0
# 511    34  31.920            0               1                        0
# 512    37  34.800            0               1                        0
# 513    57  31.160            0               1                        0
# 514    64  31.300            0               1                        0
# 516    18  36.850            0               1                        0
# 517    63  37.700            0               1                        0
# 518    27  36.080            0               1                        0
# 519    23  36.670            0               1                        0
# 520    63  32.200            0               1                        0
# ...

# %% [markdown]
# <h2><b style="color:salmon"> Sample Output </b> </h2>

# %%
# Out:
#       age     bmi  BMI_Healthy  BMI_Overweight  BMI_Slightly_Overweight  \
# 214    45  22.895            1               0                        0
# 480    59  34.800            0               1                        0
# 489    61  33.330            0               1                        0
# 511    34  31.920            0               1                        0
# 512    37  34.800            0               1                        0
# ...   ...     ...          ...             ...                      ...
# 937    62  30.875            0               1                        0
# 1070   55  26.800            0               0                        1
# 1290   24  28.500            0               0                        1
# 1293   42  26.070            0               0                        1
# 1315   43  27.800            0               0                        1
#
#       BMI_Underweight  Biological Marker  Smoker  southeast  southwest  \
# ...

# %% [markdown]
# <b> Now that you've removed the Outliers and discovered you still have a significant amount of data left - do you think removing Outliers is problematic or not? Please state your answer below and explain what your thoughts are. </b>

# %% [markdown]
# Removing outliers is not problematic in this case because we still retain a significant portion of the dataset (89.61%), which is more than enough to conduct meaningful analysis. Outliers, especially in medical insurance charges, can heavily skew statistical results like the mean and correlation, leading to inaccurate conclusions. By removing only the extreme upper outliers (based on the IQR method), we ensure that the data reflects typical patterns without being distorted by rare or exceptional cases. However, it’s important to acknowledge that outliers can carry valuable information — for instance, they might represent high-risk individuals or special medical conditions. In future analyses, it may be beneficial to analyze these outliers separately. For now, removing them helps us better understand the core trends in the data.

# %% [markdown]
# When you performed intermediate statistics for FamInsureCo using Excel, you made use of the `corr` function to calculate different linear correlations between the `medical_insurance_charges` column and the remaining variables.
#
# You'll be revisiting these functions but using Python to do so.
#
#
# ### Step 14: <span style="color:purple">Create a Correlated Dataframe</span>
# i) Using the `.corr()` method, apply this to the `intermediate_df` dataframe showcasing the R value for all variables.
# Selecting only the `medical_insurance_charges` column from the correlated dataframe, what do you observe?
#
# You'll need to ensure you use the following <a href = https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.corr.html>.corr() </a>  function.

# %% [markdown]
# <h2 style="color:teal"> Write your answer below </h2>

# %%
import pandas as pd

# Load and clean dataset
url = 'https://raw.githubusercontent.com/chrishuisb1990/practice_datasets/main/FIC_Intermediate_Descriptive_Statistics_Data.csv'
df = pd.read_csv(url)
df.columns = df.columns.str.strip()

# Step 1: Get correlation matrix
correlation_matrix = df.corr(numeric_only=True)

# Step 2: Select only the medical_insurance_charges column
correlated_with_charges = correlation_matrix['medical_insurance_charges'].sort_values(ascending=False)

# Step 3: Display the correlation values
print("📊 Correlation with medical_insurance_charges:\n")
print(correlated_with_charges)
# Out:
# 📊 Correlation with medical_insurance_charges:
#
# medical_insurance_charges    1.000000
# Smoker                       0.787251
# age                          0.299008
# Senior                       0.201118
# bmi                          0.198341
# BMI_Overweight               0.196857
# Mature Age Adult             0.137666
# southeast                    0.073982
# Biological Marker            0.057292
# northeast                    0.006349
# northwest                   -0.039905
# southwest                   -0.043210
# BMI_Underweight             -0.044960
# BMI_Healthy                 -0.106512
# Adult                       -0.114735
# BMI_Slightly_Overweight     -0.117768
# Young Adult                 -0.188178
# Name: medical_insurance_charges, dtype: float64

# %% [markdown]
# **Which variables seem to correlate with Medical Insurance Charges?**

# %% [markdown]
# <h2><b style="color:salmon"> Sample Output </b> </h2>

# %%
# Out:
# Smoker                     0.787251
# age                        0.299008
# Senior                     0.201118
# bmi                        0.198341
# BMI_Overweight             0.196857
# Mature Age Adult           0.137666
# southeast                  0.073982
# Biological Marker          0.057292
# northeast                  0.006349
# northwest                 -0.039905
# southwest                 -0.043210
# BMI_Underweight           -0.044960
# BMI_Healthy               -0.106512
# Adult                     -0.114735
# BMI_Slightly_Overweight   -0.117768
# Young Adult               -0.188178
# Name: medical_insurance_charges, dtype: float64

# %% [markdown]
# ### Step 15: <span style="color:purple">Create a Barplot of Correlated Features</span>
# <b> i) Using the correlated dataframe you've created earlier, create a horizontal barplot that shows the correlated features against `medical_insurance_charges`, in descending order. </b>

# %% [markdown]
# <h2 style="color:teal"> Write your answer below </h2>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load and prepare the data
url = 'https://raw.githubusercontent.com/chrishuisb1990/practice_datasets/main/FIC_Intermediate_Descriptive_Statistics_Data.csv'
df = pd.read_csv(url)
df.columns = df.columns.str.strip()

# Correlation with medical_insurance_charges
correlation = df.corr(numeric_only=True)['medical_insurance_charges'].sort_values(ascending=False)

# Horizontal barplot
plt.figure(figsize=(10, 6))
correlation.plot(kind='barh', color='steelblue')
plt.title('Correlation with Medical Insurance Charges')
plt.xlabel('Correlation Coefficient (R)')
plt.ylabel('Features')
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h2><b style="color:salmon"> Sample Output </b> </h2>

# %%
# Out:
# <Axes: >

# %% [markdown]
# ### Step 16: <span style="color:purple">Create a Heatmap using the Outlier Free Dataframe</span>
# Previously, you created a correlation matrix using the `intermediate_df` dataframe.
#
# We had identified that roughly 10% of the entries identified were anomalous, or in other words, outliers.
# Provided we remove these outliers from the `intermediate_df` dataframe - would this change our correlated outcomes in anyway?
#
# Let's take a look!
#
# i) Using the ~ (not) operator, remove all outliers from the `intermediate_df` dataframe using the below syntax and store this ina  new dataframe called `intermediate_df_without_outliers`:
#
#     intermediate_df_without_outliers = some_dataframe [ ~ (some_dataframe > Upper_Limit)]
#
# ii) Using the `intermediate_df_without_outliers` and `intermediate_df` dataframe, create 2 horizontal bar plots showing the correlation (R) values for the `medical_insurance_charges`.
#
# Is there any substantial differences between the correlation values now that we've removed all outliers from `medical_insurance_charges`?

# %% [markdown]
# <h2 style="color:teal"> Write your answer below </h2>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load and prepare the data
url = 'https://raw.githubusercontent.com/chrishuisb1990/practice_datasets/main/FIC_Intermediate_Descriptive_Statistics_Data.csv'
df = pd.read_csv(url)
df.columns = df.columns.str.strip()

# Step 1: Calculate Q1, Q3, IQR, Upper Limit for 'medical_insurance_charges'
Q1 = df['medical_insurance_charges'].quantile(0.25)
Q3 = df['medical_insurance_charges'].quantile(0.75)
IQR = Q3 - Q1
upper_limit = Q3 + 1.5 * IQR

# Step 2: Remove outliers (keep only rows <= upper limit)
intermediate_df_without_outliers = df[~(df['medical_insurance_charges'] > upper_limit)]

# Step 3: Correlation matrices
corr_with_outliers = df.corr(numeric_only=True)['medical_insurance_charges'].sort_values(ascending=False)
corr_without_outliers = intermediate_df_without_outliers.corr(numeric_only=True)['medical_insurance_charges'].sort_values(ascending=False)

# Step 4: Plot side-by-side comparison
plt.figure(figsize=(14, 6))

# Right plot: Without outliers
plt.subplot(1, 2, 2)
corr_without_outliers.plot(kind='barh', color='steelblue')
plt.title('Correlation WITHOUT Outliers')
plt.xlabel('Correlation Coefficient (R)')
plt.ylabel('')
plt.grid(True, axis='x', linestyle='--', alpha=0.5)

# Left plot: With outliers
plt.subplot(1, 2, 1)
corr_with_outliers.plot(kind='barh', color='salmon')
plt.title('Correlation WITH Outliers')
plt.xlabel('Correlation Coefficient (R)')
plt.ylabel('Features')
plt.grid(True, axis='x', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# <b> Do any variables stand out? If yes, list these out below your heatmap. </b>

# %% [markdown]
# <h2><b style="color:salmon"> Sample Output </b> </h2>

# %% [markdown]
# <h3> You've made it to the end of this case study — well done! </h3>
#
# This is just the start of your foundation in Python as you grow more proficient in practicing against datasets both big and small.
#
# Keep up the fantastic work and as always - if you have any questions, don't hesitate to reach out to the community, your mentor, or #slack channel for extra support! If you need, you can also reach out to the course creator, Chris Hui, via: chris.hui.sb.1990@gmail.com!
#
# <h3> Keep up the amazing work! </h3>

# %% [markdown]
# ## Appendix: Python Cheat Sheet
#
# **SELECTING COLUMNS**
#
# ```Python
# - dataframe['a'] -- Select column a from a dataframe individually
# - dataframe[['a','b']] -- Select columns a and b from a dataframe
# - dataframe[:5] -- Select the first five rows from the dataframe
# - dataframe[2:] -- Select all the rows of the dataframe starting from row 2 onwards
# - dataframe.head(n) -- Select the number of rows in the dataframe specified by n
# - dataframe.loc[row,column] -- Selects the number of rows, and columns specified with labels
# - dataframe.iloc[row,column_index] -- Select the number of rows, and columns referencing their index
#
# ```
#
# **LIBRARIES**
# ```Python
# - import pandas as pd -- This imports the pandas library that contains the methods you need to manipulate tabular data
# - import numpy as np -- This imports the numpy library that contains the np.where (IF) method you need to utilize
# - import warnings -- This is the warning library that can be imported to either highlight or hide warning messages
# - warnings. filterwarnings('ignore')--This ignores Python warning errors
# - import matplotlib.pyplot as plt -- This is the visualization library needed to create plots
#
# ```
# **OPERATORS**
# ```Python
# - < - Less than
# - > - Greater than
# - <= - Less than or equal
# - >= - Greater than or equal
# - <> - Not equal
# - = - Equal
# - & - AND (e.g. dataframe['Column']>=1) & (dataframe['Column']<=2)
# - | - OR
# ```
#
# **DESCRIPTIVE STATISTICS FUNCTIONS**
# ```Python
# - dataframe['column'].mean() - Returns the average value of a column
# - dataframe['column'].min() - Returns the minimum value of a column
# - dataframe['column'].max() - Returns the minimum value of a column
# - dataframe['column'].sum() - Returns the sum of a column
# - dataframe['column'].median() - Returns the median of a column
#
# ```
#
# **SUBSETTING COLUMNS**
# ```Python
# - dataframe['column'].isin(['A','B']) - Returns a T/F boolean list of entries matching A and B which are textual fields
# - dataframe[condition] - Provided condition is a T/F boolean expression, it will return all matching entries that are
# True
# ```
#
# **USING NP.WHERE() AS A PROXY FOR IF STATEMENTS**
# ```Python
# - np.where(dataframe['column']> 1, "Return when True", "Return when False") -- A True/False expression comparison for numerical terms.
# - np.where(dataframe['column'].isin(['A','B']),"Return when True", "Return when False") -- A True/False expression comparison for textual comparisons.
# ```
#
# **SORTING VALUES**
# ```Python
# - dataframe.groupby(['A']).sum()[['B','C']].sort_values(by=['B'], ascending=False) -- The syntax to sort a dataframe using specific columns
# - dataframe.groupby(['A']).sum()['B'].sort_values(ascending=False) -- The syntax to sort a dataframe provided you only have one numerical column to sort on.
#
# ```
#
# **DICTIONARIES AND AGGREGATIONS**
# ```Python
# - Dictionaries are special data types in Python defined by a key-value relationship.
# Syntax wise, they use the {'key': 'value'} syntax
# - .agg(['X','Y']) represents a advanced method of providing multiple descriptive statistics where X and Y represents aggregation functions (i.e. sum, mean, min, max etc.)
#
# ```
#
# **PLOTTING USING MATPLOTLIB**
# ```Python
# - PSP FS is the annotated framework to recall the steps required to create a visualization in Python
# - P - Data Preparation
# - S - Sorting the Data
# - P - Plotting the Visualization
# - F - Formatting the Visualization
# - S - Showing the Visualization
# - dataframe.plot(kind=<chart>, x=<x-axis>, y=<y-axis>) is the standard charting syntax
# in Python
# - plt.rcParams['figure.figsize'] = (10,4) - This helps set the figure size reflecting an (X,Y) sizing where X-represents the X-Axis and Y-Represents the Y-Axis.
# - plt.style.use('ggplot') - This helps set the look of the plots so they are all consistent
# with the `ggplot` theme. Other themes can be found here: https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html
#
# ```
#
# **FOR LOOPS AND MATPLOTLIB**
# ```Python
# - For Loops exist as a useful control structure in Python that helps to minimize repetitive tasks through the use of iterators such as the example below:
#
#     for iterator in list_example:
#         df[iterator].plot(kind='bar')
#         plt.title(iterator)
#         plt.show()
# ```
